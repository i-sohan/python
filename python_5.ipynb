# %%
from datetime import date, time, datetime as dt,timedelta as td

# %%
#create time
time1=time(12,30,40,124253)
print(time1)
# Out:
# 12:30:40.124253

# %%
time1.second
# Out:
# 40

# %%
time1.microsecond
# Out:
# 124253

# %%
#use date time module to print current date and time
current=dt.now()
print(current)
# Out:
# 2026-07-13 09:16:07.603235

# %%
#strftime()-- format the date and time according to the pattern we provide and it cnverts it into string
current.strftime("%Y")
# Out:
# '2026'

# %%
current.strftime("%Y/%m/%d")
# Out:
# '2026/07/13'

# %%
current.strftime("%T")
# Out:
# '09:16:07'

# %%
#calculate date after 5000 days
from datetime import date, time, datetime as dt,timedelta as td
future=dt.today()+td(days=100000)
print(future)
# Out:
# 2300-04-28 09:26:24.425953

# %%
future.isoweekday()
# Out:
# 6

# %% [markdown]
# #Data Structures
#
# A data structure is a way of organizing and storing data so it can be accessed and modified efficiently.
#
# A list is like a shopping list.
# A tuple is like your date of birth. It shouldn't change.
# A set is like a collection of unique student IDs.
# A dictionary is like an English dictionary, where every word (key) has a meaning (value).

# %% [markdown]
# #List
# All the values are inside the brackets

# %%
list=[1,2,2,4,5,6,7,7,8]

# %%
#indexing on list
list
list[3]
# Out:
# 4

# %%
list[-3]
# Out:
# 7

# %%
#reverse the list
list[::-1]
# Out:
# [8, 7, 7, 6, 5, 4, 2, 2, 1]

# %%
list2=[1,2,3,4, [2,3,4], 4,5]
list2[4][1]
# Out:
# 3

# %%
#updating the list
list
# Out:
# [1, 2, 2, 4, 5, 10, 7, 7, 10]

# %%
list[5]=10

# %%
list
# Out:
# [1, 2, 2, 4, 5, 10, 7, 7, 10]

# %%
list
# Out:
# [1, 2, 2, 4, 5, 10, 7, 7, 10]

# %%
#Functions on list
#append() -- Inserts the new value at the end of the list

# %%
list.append(4)
list
# Out:
# [1,
#  2,
#  2,
#  4,
#  5,
#  10,
#  7,
#  7,
#  10,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4]

# %%
#extend() --add the multiple value at the end of the list
list2=[2,3,3,3,4,5,6,7,8,9,9]
list2.extend([10,12,13])
list2
# Out:
# [2, 3, 3, 3, 4, 5, 6, 7, 8, 9, 9, 10, 12, 13]

# %%
#insert() --add a value at the certain index location
list2.insert(2,17)
list2
# Out:
# [2, 3, 17, 17, 3, 3, 4, 5, 6, 7, 8, 9, 9, 10, 12, 13]

# %%
#Sort() --sorts the list in the ascending order
list2.sort()
list2
# Out:
# [2, 3, 3, 3, 4, 5, 6, 7, 8, 9, 9, 10, 12, 13, 17, 17]

# %%
#sort in descending
list2.sort(reverse=True)
list2
# Out:
# [17, 17, 13, 12, 10, 9, 9, 8, 7, 6, 5, 4, 3, 3, 3, 2]

# %%
#pop() -- deletes the last element from the list
list2.pop(5)
list2
# Out:
# [17, 17, 13, 12, 10, 9, 8, 7, 6, 5, 4, 3, 3, 3]

# %%
#remove() -- removes based on the value
list2.remove(17)
list2
# Out:
# [17, 13, 12, 10, 9, 8, 7, 6, 5, 4, 3, 3, 3]

# %%
#del -- keyword removed using index
del list2[6]
list2
# Out:
# [17, 13, 12, 10, 9, 8, 6, 5, 4, 3, 3, 3]

# %%
#clear() --it deletes all the elements from list 
list2.clear()
list2
# Out:
# []

# %%
#joining multiple list

# %%
list1=[2,3,4,5,65,6,6]

# %%
list2=['hello',2.3,4,True,-5,-6]

# %%
list5=list1+list2
list5
# Out:
# [2, 3, 4, 5, 65, 6, 6, 'hello', 2.3, 4, True, -5, -6]

# %%
list1.extend(list2)
list1
# Out:
# [2,
#  3,
#  4,
#  5,
#  65,
#  6,
#  6,
#  'hello',
#  2.3,
#  4,
#  True,
#  -5,
#  -6,
#  'hello',
#  2.3,
#  4,
#  True,
#  -5,
#  -6]

# %%
#list membership

# %%
vowels=['a','e','i','o','u']
char=input("Enter a char:")
if char in vowels:
    print("It is a vowel")
else:
    print("not a vowel")
# Out:
# not a vowel

# %%
#Tuples
#It is a collection of elements inside()
#It is immutable datastructure that is elements once created in tuple cannot be changed or deleted
#Tuple is only prefered when you dont change data over data

# %%
t1=()#empty tuple
t1
type(t1)
# Out:
# tuple

# %%
t2=(4,5,6,7,8,9,-3,-4)
t2
# Out:
# (4, 5, 6, 7, 8, 9, -3, -4)

# %%
t3=("hello",5.3,True,False,[2,3])
t3
# Out:
# ('hello', 5.3, True, False, [2, 3])

# %%
t4=(6,3,(4,8),3)
t4
# Out:
# (6, 3, (4, 8), 3)

# %%
#Indexing and Slicing on Tuple

# %%
t2
# Out:
# (4, 5, 6, 7, 8, 9, -3, -4)

# %%
t2[-4]
# Out:
# 8

# %%
#functions in the tuple

# %%
t4
# Out:
# (6, 3, (4, 8), 3)

# %%
#count() -- returns no.of occurence of certain elements
t4.count(3)
# Out:
# 2

# %%
#index() -- returns index position of certain element
t4.index(3)
# Out:
# 1

# %%
#sorted()-- sorts the tuple temporarily and return sthe result in form of list
t2
# Out:
# (4, 5, 6, 7, 8, 9, -3, -4)

# %%
sorted(t2)
# Out:
# [-4, -3, 4, 5, 6, 7, 8, 9]

# %%
t2
# Out:
# (4, 5, 6, 7, 8, 9, -3, -4)

# %%
#Convert the tuple to the list
#use typecasting

# %%
t3
# Out:
# ('hello', 5.3, True, False, [2, 3])

# %%
=  list(t3)
# Out:
# ['hello', 5.3, True, False, [2, 3]]
