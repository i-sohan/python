# %% [markdown]
# 1) Write a program to concatenate two strings "Good Morning!" and "Have a nice day!" and print the combined string using a space in between.

# %%
a = "Good Morning!"
b = "Have a nice day!"
combined = a + " " + b
print(combined)
# Out:
# Good Morning! Have a nice day!

# %% [markdown]
# 2) Can you give multiline comment & explain what is the meaning of keywords?

# %%
"""This is a multi-line comment in Python.
It starts and ends with triple double quotes.
"""

# Keywords are reserved words in Python.
# They have special meaning and cannot be used as variable names.
# Examples: if, else, while, for, def, class, return, import
# Out:
# 'This is a multi-line comment in Python.\nIt starts and ends with triple double quotes.\n'

# %% [markdown]
# 3) Write a program to slice a string str1="Hello Everyone". Show output for str1[2:7], str1[:4], str1[5:], str1[-6:-1], str1[-5:-2]

# %%
str1="Hello Everyone"
str1[2:7]
# Out:
# 'llo E'

# %%
str1[:4]
# Out:
# 'Hell'

# %%
str1[5:]
# Out:
# ' Everyone'

# %%
str1[-6:-1]
# Out:
# 'eryon'

# %%
str1[-5:-2]
# Out:
# 'ryo'

# %% [markdown]
# 4) We have variable x=22+5j. Can you check the type of variable x?

# %%
x=22+5j
type(x)
# Out:
# complex

# %% [markdown]
# 5) We have variable y=88.7. Convert the value to integer.

# %%
y=int(88.7)
type(y)
# Out:
# int

# %% [markdown]
# 6) Use partition() to split the string, str3="Twinkle Twinkle little star" based on argument string "little"

# %%
str3 = "Twinkle Twinkle little star"
result = str3.partition("little")
print(result)
# Out:
# ('Twinkle Twinkle ', 'little', ' star')

# %% [markdown]
# 7) What is the output of x=int(5.7)+float(4)+int(True)?

# %%
x=int(5.7)+float(4)+int(True)
x
# Out:
# 10.0

# %% [markdown]
# 8) We have string, str="Have a nice day!". Can you count & print number of occurances of letter 'a'?

# %%
str = "Have a nice day!"
count_a = str.count('a')
print(count_a)
# Out:
# 3

# %% [markdown]
# 9) str1="   Thank you  ". Remove whitespaces from beginning & end of string.

# %%
str1 = "   Thank you  "
print(str1.strip())
# Out:
# Thank you

# %% [markdown]
# 10) Split str="Have a nice day!" based on letter 'a'

# %%
str = "Have a nice day!"
result = str.split('a')
print(result)
# Out:
# ['H', 've ', ' nice d', 'y!']

# %% [markdown]
# 11) Create a string str5="Good Day". How to check if letter D is present in it or not?

# %%
str5 = "Good Day"
print('D' in str5)
# Out:
# True

# %% [markdown]
# 12) Use string functions to split your entire string based on 's

# %%
text = "This is a sample string"
result = text.split('s')
print(result)
# Out:
# ['Thi', ' i', ' a ', 'ample ', 'tring']
