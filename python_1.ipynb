# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
5+2
# Out:
# 7

# %% [markdown]
# ## Libraries in Python
# They are collection of the prewritten code

# %%
# !pip install numpy

# %%
# !pip install pandas

# %% [markdown]
# #keywords in python
#
# They are the predefined words

# %%
import keyword
print(keyword.kwlist)
len(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']
# 35

# %% [markdown]
# Variables in Python
#
# They are the reserved memory to store any value and  created the moment we assign the value

# %%
x=8
x
# Out:
# 8

# %% [markdown]
# Data Types in python

# %%
import sys

# %%
x=5
print(type(x))
print(sys.getsizeof(x))
# Out:
# <class 'int'>
# 28

# %%
y=5+4j
print(type(y))
# Out:
# <class 'complex'>

# %%
q="ArithmeticError"
print(type(q))
print(sys.getsizeof(q))
# Out:
# <class 'str'>
# 56
