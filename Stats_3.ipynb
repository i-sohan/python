# %% [markdown]
# # Statistics for Data Science
# This notebook covers:
# - Descriptive Statistics
# - Probability Distributions
# - Hypothesis Testing
# - Correlation and Regression
# - Bayesian Statistics
# - Time Series Analysis
# - Statistical Sampling Methods
#
# Each section includes explanations and runnable Python examples.

# %% [markdown]
# # Descriptive Statistics
# Descriptive statistics summarize data.
#
# - Mean
# - Median
# - Mode
# - Variance
# - Standard Deviation
#
# ```python
# import numpy as np
# import matplotlib.pyplot as plt
#
# data=[10,12,15,18,20,22,25,28,30]
# print("Mean:",np.mean(data))
# print("Median:",np.median(data))
# print("Std:",np.std(data))
#
# plt.hist(data,bins=5)
# plt.title("Histogram")
# plt.show()
# ```

# %% [markdown]
# # Probability Distributions
#
# Normal, Binomial, Poisson distributions.
#
# ```python
# import numpy as np
# import matplotlib.pyplot as plt
# from scipy.stats import norm
#
# x=np.linspace(-4,4,200)
# plt.plot(x,norm.pdf(x))
# plt.title("Normal Distribution")
# plt.show()
# ```

# %% [markdown]
# # Hypothesis Testing
#
# Example: One-sample t-test
#
# ```python
# from scipy.stats import ttest_1samp
# import numpy as np
#
# sample=np.array([72,75,71,70,74,73,72,71])
# t,p=ttest_1samp(sample,70)
# print(t,p)
# ```

# %% [markdown]
# # Correlation and Regression
#
# ```python
# import numpy as np
# import matplotlib.pyplot as plt
# from sklearn.linear_model import LinearRegression
#
# x=np.arange(1,11).reshape(-1,1)
# y=np.array([2,4,5,4,5,7,8,9,10,12])
#
# model=LinearRegression().fit(x,y)
# plt.scatter(x,y)
# plt.plot(x,model.predict(x))
# plt.show()
# ```

# %% [markdown]
# # Bayesian Statistics
#
# Bayes' theorem:
#
# P(A|B)=P(B|A)P(A)/P(B)
#
# ```python
# prior=0.01
# sensitivity=0.95
# false_positive=0.05
# posterior=(sensitivity*prior)/((sensitivity*prior)+(false_positive*(1-prior)))
# print(posterior)
# ```

# %% [markdown]
# # Time Series Analysis
#
# ```python
# import pandas as pd
# import matplotlib.pyplot as plt
#
# dates=pd.date_range("2025-01-01",periods=12,freq="M")
# sales=[20,22,23,25,27,30,31,35,36,40,42,45]
# ts=pd.Series(sales,index=dates)
# ts.plot(marker='o')
# plt.title("Monthly Sales")
# plt.show()
# ```

# %% [markdown]
# # Statistical Sampling Methods
#
# - Simple Random Sampling
# - Stratified Sampling
# - Cluster Sampling
# - Systematic Sampling
#
# ```python
# import pandas as pd
#
# df=pd.DataFrame({"id":range(1,101)})
# sample=df.sample(10,random_state=42)
# print(sample)
# ```
